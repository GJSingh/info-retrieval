# %% [markdown]
# <a href="https://colab.research.google.com/github/GJSingh/info-retrieval/blob/master/Identify_pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'dataset_pokemon/pokemon/'
path = Path(base_dir)
#path = base_dir + 'train'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
path
# Out:
# PosixPath('/content/gdrive/My Drive/dataset_pokemon/pokemon')

# %%
tfms = get_transforms(do_flip=False)

# %% [markdown]
# path = Path(base_dir + 'dataset_pokemon/pokemon')
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)

# %%
#data = ImageDataBunch.from_folder(path,ds_tfms=tfms, size = 26)
data = (ImageList.from_folder(path).split_by_rand_pct() .label_from_folder() .transform(tfms, size=224) .databunch())

# %%
type(data)
# Out:
# fastai.vision.data.ImageDataBunch

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abomasnow', 'Abomasnow(Mega)', 'Abra', 'Absol', 'Absol(Mega)', 'Accelgor', 'Aegislash', 'Aerodactyl', 'Aerodactyl(Mega)', 'Aggron', 'Aggron(Mega)', 'Aipom', 'Alakazam', 'Alakazam(Mega)', 'Alomomola', 'Altaria', 'Altaria(Mega)', 'Amaura', 'Ambipom', 'Amoonguss', 'Ampharos', 'Ampharos(Mega)', 'Anorith', 'Araquanid', 'Arbok', 'Arcanine', 'Arceus', 'Archen', 'Archeops', 'Ariados', 'Armaldo', 'Aromatisse', 'Aron', 'Articuno', 'Audino', 'Audino(Mega)', 'Aurorus', 'Avalugg', 'Axew', 'Azelf', 'Azumarill', 'Azurill', 'Bagon', 'Baltoy', 'Banette', 'Banette(Mega)', 'Barbaracle', 'Barboach', 'Basculin(Blue-Striped)', 'Basculin(Red-Striped)', 'Bastiodon', 'Bayleef', 'Beartic', 'Beautifly', 'Beedrill', 'Beedrill(Mega)', 'Beheeyem', 'Beldum', 'Bellossom', 'Bellsprout', 'Bergmite', 'Bewear', 'Bibarel', 'Bidoof', 'Binacle', 'Bisharp', 'Blacephalon', 'Blastoise', 'Blastoise(Mega)', 'Blaziken', 'Blaziken(Mega)', 'Blissey', 'Blitzle', 'Boldore', 'Bonsly', 'Bouffalant', 'Bounsweet', 'Braixen', 'Braviar
# ...

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:03<00:00, 28933883.81it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.634837</td>
#       <td>4.380448</td>
#       <td>0.744508</td>
#       <td>1:21:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.469713</td>
#       <td>1.574872</td>
#       <td>0.335639</td>
#       <td>04:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.431147</td>
#       <td>1.095376</td>
#       <td>0.235557</td>
#       <td>04:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.958736</td>
#       <td>1.032273</td>
#       <td>0.223352</td>
#       <td>04:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.train_loss=0.958736
learn.valid_loss=1.032273
learn.error_rate=0.223352

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-d745160313a7> in <module>()
# ----> 1 interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in plot_confusion_matrix(self, normalize, title, cmap, slice_size, norm_dec, plot_txt, return_fig, **kwargs)
#     198                 plt.text(j, i, coeff, horizontalalignment="center", verticalalignment="center", color="white" if cm[i, j] > thresh else "black")
#     199
# --> 200         plt.tight_layout()
#     201         plt.ylabel('Actual')
#     202         plt.xlabel('Predicted')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1380         labels) will fit into. Default is (0, 0, 1, 1).
#    1381     """
# -> 1382     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1383
# ...

# %%
interp.most_confused(min_val=2)
# Out:
# [('Arcanine', 'Regice', 11),
#  ('Unown', 'Regice', 8),
#  ('Talonflame', 'Regice', 7),
#  ('Aerodactyl', 'Geodude(Alola)', 6),
#  ('Braixen', 'Regice', 6),
#  ('Ditto', 'Geodude(Alola)', 6),
#  ('Froakie', 'Elgyem', 6),
#  ('Furret', 'Geodude(Alola)', 6),
#  ('Gallade(Mega)', 'Regice', 6),
#  ('Gardevoir', 'Regice', 6),
#  ('Gastly', 'Liepard', 6),
#  ('Pidgey', 'Regice', 6),
#  ('Rhydon', 'Geodude(Alola)', 6),
#  ('Tangrowth', 'Elgyem', 6),
#  ('Typhlosion', 'Regice', 6),
#  ('Absol(Mega)', 'Elgyem', 5),
#  ('Arbok', 'Geodude(Alola)', 5),
#  ('Aromatisse', 'Geodude(Alola)', 5),
#  ('Bagon', 'Elgyem', 5),
#  ('Chespin', 'Regice', 5),
#  ('Cinccino', 'Elgyem', 5),
#  ('Crobat', 'Elgyem', 5),
#  ('Dratini', 'Elgyem', 5),
#  ('Ekans', 'Regice', 5),
#  ('Fennekin', 'Regice', 5),
#  ('Floatzel', 'Regice', 5),
#  ('Gengar(Mega)', 'Geodude(Alola)', 5),
#  ('Hawlucha', 'Regice', 5),
#  ('Incineroar', 'Regice', 5),
#  ('Jirachi', 'Geodude(Alola)', 5),
#  ('Jolteon', 'Regice', 5),
# ...
